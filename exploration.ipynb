# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load input into numpy ndarray

# %%
file = "data/sonar.all-data"

# %%
def clean_cell(cell: str):
    if cell == "R\n" or "M\n":
        return cell.strip("\n")
    return float(cell)

f = open(file)
M = []
for line in f:
    M.append([clean_cell(x) for x in line.split(',')])

# %%
M[0]
# Out:
# ['0.0200',
#  '0.0371',
#  '0.0428',
#  '0.0207',
#  '0.0954',
#  '0.0986',
#  '0.1539',
#  '0.1601',
#  '0.3109',
#  '0.2111',
#  '0.1609',
#  '0.1582',
#  '0.2238',
#  '0.0645',
#  '0.0660',
#  '0.2273',
#  '0.3100',
#  '0.2999',
#  '0.5078',
#  '0.4797',
#  '0.5783',
#  '0.5071',
#  '0.4328',
#  '0.5550',
#  '0.6711',
#  '0.6415',
#  '0.7104',
#  '0.8080',
#  '0.6791',
#  '0.3857',
#  '0.1307',
#  '0.2604',
#  '0.5121',
#  '0.7547',
#  '0.8537',
#  '0.8507',
#  '0.6692',
#  '0.6097',
#  '0.4943',
#  '0.2744',
#  '0.0510',
#  '0.2834',
#  '0.2825',
#  '0.4256',
#  '0.2641',
#  '0.1386',
#  '0.1051',
#  '0.1343',
#  '0.0383',
#  '0.0324',
#  '0.0232',
#  '0.0027',
#  '0.0065',
#  '0.0159',
#  '0.0072',
#  '0.0167',
#  '0.0180',
#  '0.0084',
#  '0.0090',
#  '0.0032',
#  'R']

# %%
M = np.array([np.array(i) for i in M])

# %% [markdown]
# # Exploration using pandas

# %%
df = pd.DataFrame(M)

# %%
df
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
#          9   ...      51      52      53      54      55      56      57  \
# 0    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1    0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2    0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3    0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4    0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.2684  ...  0.0116  0.0098  0.0199  0.0033  0.0101  0.0065  0.0115
# 204  0.2154  ...  0.0061  0.0093  0.0135  0.0063  0.0063  0.0034  0.0032
# 205  0.2529  ...  0.0160  0.0029  0.0051  0.0062  0.0089  0.0140  0.0138
# 206  0.2354  ...  0.0086  0.0046  0.0126  0.0036  0.0035  0.0034  0.0079
# 207  0.2354  ...  0.0146  0.0129  0.0047  0.0039  0.0061  0.0040  0.0036
#
#          58      59 60
# 0    0.0090  0.0032  R
# 1    0.0052  0.0044  R
# 2    0.0095  0.0078  R
# 3    0.0040  0.0117  R
# 4    0.0107  0.0094  R
# ..      ...     ... ..
# 203  0.0193  0.0157  M
# 204  0.0062  0.0067  M
# 205  0.0077  0.0031  M
# 206  0.0036  0.0048  M
# 207  0.0061  0.0115  M
#
# [208 rows x 61 columns]

# %%
df.groupby(df.columns[60])[60].count()
# Out:
# 60
# M    111
# R     97
# Name: 60, dtype: int64

# %%
df.groupby(df.columns[60])[60].count().to_numpy()/ df.count().to_numpy()[0]
# Out:
# array([0.53365385, 0.46634615])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       208 non-null    object
#  1   1       208 non-null    object
#  2   2       208 non-null    object
#  3   3       208 non-null    object
#  4   4       208 non-null    object
#  5   5       208 non-null    object
#  6   6       208 non-null    object
#  7   7       208 non-null    object
#  8   8       208 non-null    object
#  9   9       208 non-null    object
#  10  10      208 non-null    object
#  11  11      208 non-null    object
#  12  12      208 non-null    object
#  13  13      208 non-null    object
#  14  14      208 non-null    object
#  15  15      208 non-null    object
#  16  16      208 non-null    object
#  17  17      208 non-null    object
#  18  18      208 non-null    object
#  19  19      208 non-null    object
#  20  20      208 non-null    object
#  21  21      208 non-null    object
#  22  22      208 non-null    object
#  23  23      208 non-null    object
#  24  24      208 non-null    object
#  25  25      208 non-null    object
#  26  26      208 non-null    object
#  27  27      208 non-null    object
describe()
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# std      0.061788    0.085152    0.118387    0.134416  ...    0.012008
# min      0.003300    0.005500    0.007500    0.011300  ...    0.000000
# 25%      0.080900    0.080425    0.097025    0.111275  ...    0.008425
# 50%      0.106950    0.112100    0.152250    0.182400  ...    0.013900
# 75%      0.154000    0.169600    0.233425    0.268700  ...    0.020825
# max      0.372900    0.459000    0.682800    0.710600  ...    0.100400
#
#                51          52          53          54          55          56  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.013420    0.010709    0.010941    0.009290    0.008222    0.007820
# std      0.009634    0.007060    0.007301    0.007088    0.005736    0.005785
# min      0.000800    0.000500    0.001000    0.000600    0.000400    0.000300
# 25%      0.007275    0.005075    0.005375    0.004150    0.004400    0.003700
# 50%      0.011400    0.009550    0.009300    0.007500    0.006850    0.005950
# 75%      0.016725    0.014900    0.014500    0.012100    0.010575    0.010425
# max      0.070900    0.039000    0.035200    0.044700    0.039400    0.035500
#
#                57          58          59
# count  208.000000  208.000000  208.000000
# mean     0.007949    0.007941    0.006507
# std      0.006470    0.006181    0.005031
# min      0.000300    0.000100    0.000600
# 25%      0.003600    0.003675    0.003100
# 50%      0.005800    0.006400    0.005300
# 75%      0.010350    0.010325    0.008525
# max      0.044000    0.036400    0.043900
#
# [8 rows x 60 columns]

# %% [markdown]
# # Preparing train and val splits

# %%
np.random.shuffle(M)
print(M)
# Out:
# [['0.0156' '0.0210' '0.0282' ... '0.0048' '0.0024' 'M']
#  ['0.0200' '0.0371' '0.0428' ... '0.0090' '0.0032' 'R']
#  ['0.0100' '0.0194' '0.0155' ... '0.0053' '0.0019' 'R']
#  ...
#  ['0.1313' '0.2339' '0.3059' ... '0.0178' '0.0231' 'M']
#  ['0.0162' '0.0253' '0.0262' ... '0.0048' '0.0019' 'M']
#  ['0.0269' '0.0383' '0.0505' ... '0.0055' '0.0057' 'M']]

# %%
x = M[:, :60].astype(float)
y = M[:, 60]

# %%
x
# Out:
# array([[0.0156, 0.021 , 0.0282, ..., 0.0056, 0.0048, 0.0024],
#        [0.02  , 0.0371, 0.0428, ..., 0.0084, 0.009 , 0.0032],
#        [0.01  , 0.0194, 0.0155, ..., 0.0019, 0.0053, 0.0019],
#        ...,
#        [0.1313, 0.2339, 0.3059, ..., 0.0127, 0.0178, 0.0231],
#        [0.0162, 0.0253, 0.0262, ..., 0.01  , 0.0048, 0.0019],
#        [0.0269, 0.0383, 0.0505, ..., 0.0027, 0.0055, 0.0057]])

# %%
def normalise_2darray(d2array):
    output_array = []
    for array in d2array:
        x = (array - np.mean(array)) / np.std(array)
        # x[x < 0] *= -1
        # x = (x-np.min(x))/(np.max(x)-np.min(x))
        output_array.append(x)
    return np.asarray(output_array)

x_norm = normalise_2darray(x)
x_norm
# Out:
# array([[-0.92469664, -0.90314985, -0.87442079, ..., -0.96459811,
#         -0.96779023, -0.97736658],
#        [-1.01521694, -0.94884556, -0.92672176, ..., -1.0602408 ,
#         -1.05791198, -1.08042392],
#        [-1.05183108, -1.02061915, -1.03356878, ..., -1.07872647,
#         -1.06743705, -1.07872647],
#        ...,
#        [-0.74720816, -0.13979565,  0.28645874, ..., -1.44934386,
#         -1.41915084, -1.38777378],
#        [-0.84603677, -0.814661  , -0.8115579 , ..., -0.86741367,
#         -0.88534268, -0.89534156],
#        [-1.09240367, -1.05169475, -1.00812906, ..., -1.17882085,
#         -1.16882217, -1.16810798]])

# %%
x_norm.shape
# Out:
# (208, 60)

# %%
df_x = pd.DataFrame(x_norm)
df_x.describe()
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean    -0.905851   -0.870174   -0.849208   -0.811742   -0.737432   -0.634561
# std      0.111001    0.127243    0.150952    0.191882    0.209493    0.201654
# min     -1.197464   -1.205673   -1.104323   -1.208466   -1.110904   -1.149395
# 25%     -0.985215   -0.949379   -0.928599   -0.912498   -0.865307   -0.762831
# 50%     -0.895490   -0.867641   -0.858324   -0.828026   -0.751082   -0.666919
# 75%     -0.830437   -0.800557   -0.786930   -0.734875   -0.632957   -0.523199
# max     -0.632045   -0.139796    0.286459    0.999843    0.849470    0.346169
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean    -0.573192   -0.525316   -0.369318   -0.261789  ...   -0.954853
# std      0.210451    0.280962    0.379070    0.442182  ...    0.114332
# min     -1.130276   -1.491969   -1.031097   -1.140694  ...   -1.432175
# 25%     -0.716553   -0.690677   -0.609995   -0.556247  ...   -1.034518
# 50%     -0.581181   -0.553115   -0.421707   -0.351527  ...   -0.950455
# 75%     -0.438019   -0.405121   -0.233920   -0.053679  ...   -0.871233
# max      0.310287    0.546937    1.204129    1.584394  ...   -0.716869
#
#                51          52          53          54          55          56  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean    -0.964129   -0.974457   -0.973704   -0.979442   -0.983930   -0.984970
# std      0.113664    0.119932    0.118032    0.117673    0.121560    0.118828
# min     -1.310219   -1.400206   -1.433359   -1.417967   -1.516834   -1.461776
# 25%     -1.045272   -1.058507   -1.055521   -1.067268   -1.064559   -1.069791
# 50%     -0.960358   -0.968410   -0.963195   -0.976132   -0.975439   -0.981671
# 75%     -0.874659   -0.879817   -0.886139   -0.894487   -0.894213   -0.897099
# max     -0.726459   -0.680906   -0.695976   -0.728514   -0.733994   -0.746324
#
#                57          58          59
# count  208.000000  208.000000  208.000000
# mean    -0.984513   -0.984324   -0.989675
# std      0.118202    0.117508    0.119500
# min     -1.449344   -1.419151   -1.387774
# 25%     -1.071869   -1.064610   -1.080157
# 50%     -0.976891   -0.979803   -0.985795
# 75%     -0.895485   -0.896350   -0.897421
# max     -0.745297   -0.738104   -0.743584
#
# [8 rows x 60 columns]

# %%
np.array(np.unique(y, return_counts=True)).T
# Out:
# array([['M', '111'],
#        ['R', '97']], dtype='<U21')

# %%
y.shape
# Out:
# (208,)

# %%
def encode_classes(target):
    encoded_target = []
    encoding_dict = {'R': 0, 'M': 1}
    
    for x in target:
        encoded_target.append(encoding_dict.get(x))
            
    return np.asarray(encoded_target), encoding_dict

y_enc, encoding = encode_classes(y)
np.array(np.unique(y_enc, return_counts=True)).T
# Out:
# array([[  0,  97],
#        [  1, 111]], dtype=int64)

# %%
print(x_norm.shape, y_enc.shape)
# Out:
# (208, 60) (208,)

# %%
corr_arr = []
for idx, row in enumerate(x_norm):
    arr = np.asarray(list(row) + [y_enc[idx]])
    corr_arr.append(arr)
corr_arr = np.asarray(corr_arr)
corr_map = np.corrcoef(corr_arr, rowvar=False).round(2)
corr_map = corr_map[:, 60]  # keep only final column of the heatmap | correlation to target class
corr_map = corr_map.reshape((61, 1))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(corr_map[:15], annot=True)
plt.show()

# %%
sns.heatmap(corr_map[15:30], annot=True)
plt.show()

# %%
sns.heatmap(corr_map[30:45], annot=True)
plt.show()

# %%
sns.heatmap(corr_map[45:60], annot=True)
plt.show()

# %%
sns.heatmap(corr_map[60:61], annot=True)
plt.show()

# %%
to_drop = []
for idx, value in enumerate(corr_map):
    if value > -0.1 and value < 0.1:
        to_drop.append(idx)
to_drop
# Out:
# [1,
#  2,
#  3,
#  4,
#  5,
#  6,
#  7,
#  14,
#  15,
#  16,
#  17,
#  22,
#  23,
#  24,
#  25,
#  26,
#  27,
#  28,
#  29,
#  38,
#  40,
#  41,
#  48]

# %%
len(to_drop)
# Out:
# 23

# %%
x_norm.shape
# Out:
# (208, 60)

# %%
x_norm = np.delete(x_norm, to_drop, axis=1)
x_norm.shape
# Out:
# (208, 37)
